# %% [markdown]
# <a href="https://colab.research.google.com/github/Archana3105/fmml-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 08:49:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.2’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  70.9MB/s    in 1.0s
#
# 2024-03-27 08:49:54 (70.9 MB/s) - ‘arxiv-paper-data.json.2’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 16  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12205  1710.05384v2  We analyze the dynamics of an online algorithm...    cs
# 33426   1406.7399v1  The new type of Mobile Ad hoc Network which is...    cs
# 7219   1711.02545v1  A key challenge in online learning is that cla...  stat
# 7158   1710.09567v1  We present an algorithm for classification tas...  stat
# 8292   1506.07704v2  We present a novel detection method using a de...    cs
# ...             ...                                                ...   ...
# 22450  1607.03842v1  An important problem in sequential decision-ma...  stat
# 12118  1708.07967v1  This paper presents VEC-NBT, a variation on th...  stat
# 7248   1711.04755v1  Generative Adversarial Networks (GANs) are a p...  stat
# 1329    1412.5104v1  Convolutional Neural Networks (ConvNets) have ...    cs
# 12312  1711.07033v3  This paper presents a novel decentralized high...  stat
#
#                                                    title  year  \
# 12205  The Scaling Limit of High-Dimensional Online I...  2017
# 33426  Intelligent Emergency Message Broadcasting in ...  2014
# 7219   Online Learning for Changing Environments usin...  2017
# 7158   Big Data Classification Using Augmented Decisi...  2017
# 8292   AttentionNet: Aggregating Weak Directions for ...  2015
# ...                                                  ...   ...
# 22450  Safe Policy Improvement by Minimizing Robust B...  2016
# 12118  Faster Clustering via Non-Backtracking Random ...  2017
# 7248     ACtuAL: Actor-Critic Under Adversarial Learning  2017
# 1329   Locally Scale-Invariant Convolutional Neural N...  2014
# 12312  Decentralized High-Dimensional Bayesian Optimi...  2017
#
#                                                 keywords
# 12205  [algorithm, independent, component, dimensiona...
# 33426  [vehicular, environment, optimization, content...
# 7219   [challenge, classical, algorithms, environment...
# 7158   [algorithm, classification, experiments, condu...
# 8292   [detection, convolutional, attentionnet, detec...
# ...                                                  ...
# 22450  [important, sequential, uncertainty, guarantee...
# 12118  [variation, unsupervised, clustering, techniqu...
# 7248   [generative, adversarial, framework, generativ...
# 1329   [convolutional, excellent, classification, exc...
# 12312  [decentralized, dimensional, optimization, alg...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12205    [algorithm, independent, component, dimensiona...
# 33426    [vehicular, environment, optimization, content...
# 7219     [challenge, classical, algorithms, environment...
# 7158     [algorithm, classification, experiments, condu...
# 8292     [detection, convolutional, attentionnet, detec...
#                                ...
# 22468    [numerical, categorical, attributes, routinely...
# 1778     [revolutionize, application, increasing, under...
# 3776     [observations, efficient, constraint, graduall...
# 29523    [requirement, initialization, optimization, re...
# 9914     [increasing, availability, developing, effecti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8894 words.
# Out of those 4584 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="40c85f7f-8156-445e-9ece-b6e2d7bd741c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40c85f7f-8156-445e-9ece-b6e2d7bd741c")) {                    Plotly.newPlot(                        "40c85f7f-8156-445e-9ece-b6e2d7bd741c",                        [{"x":["achieving","practical","asymptotically","stochastic","efficiency","dimension","estimates","deterministic","variables","independently","computational","understanding","providing","asymptotic","interesting","minimization","functionals","nonlinear","numerical","effective","algorithm","solutions","characterized","information","component","associated","simulations","empirical","exploiting","performance","coordinate","statistical","efficiently","particular","independent","dimensional","decoupled","algorithms","dimensions","efficient","optimization","broadcast","environment","intelligent","broadcasting","distribute","geographical","vehicular","emergency","dissemination","contention","reduction","describes","environments","adaptivity","classical","complexity","outperforms","scenarios","dependent","knowledge","sometimes","consecutive","parameter","challenge","augmented","experiments","interpreted","determine","distributions","homogeneous","attributes","classifier","conducted","construction","classification","detection","directions","aggregating","regression","iterative","architecture","separated","predictions","converges","convolutional","quantized","probabilistic","previously","application","difficulty","capturing","encountered","automatically","hierarchical","approximations","extraction","different","assumption","predictive","typically","intractable","variational","collections","demonstrate","significantly","regularities","unobserved","estimated","procedure","indicative","inference","applicable","traditional","approaches","formatting","including","locations","gazetteer","heuristic","experimental","travelling","inferring","identification","predicted","prediction","predicting","variations","classifiers","geographic","granularities","dictionary","suboptimal","discriminant","convergence","considers","literature","conditions","observations","consistent","theoretical","selection","distributed","behaviours","simulating","potential","metaphors","institutional","institutions","aggregate","identifies","overarching","techniques","designing","architectural","structures","reproduce","specialized","behaviour","intelligence","proposing","conceived","applications","components","interfacing","artificial","organization","challenges","narrative","representation","integration","interpret","resulting","ontologies","disambiguation","background","polysemous","extending","semantics","discourse","constructs","languages","interpretation","systematically","functional","procedural","demonstrated","controlled","preprocessing","automating","observational","adaptation","importance","widespread","justification","employment","counterfactual","answering","representations","accumulation"],"y":[85,140,15,128,166,43,82,40,132,37,296,159,105,17,65,59,2,57,79,262,818,150,35,692,95,105,54,147,85,892,33,178,146,262,124,184,7,618,37,388,315,4,137,65,3,4,6,3,7,2,4,83,77,93,1,106,225,263,75,73,329,25,6,116,164,28,605,12,80,140,15,58,154,94,69,497,319,41,13,102,73,209,12,82,28,402,10,154,90,234,37,44,20,204,102,39,124,722,70,61,104,25,54,17,578,244,10,7,70,133,8,210,50,176,405,2,238,45,2,62,376,4,25,116,44,214,91,86,123,6,5,55,19,14,124,39,138,134,74,84,177,162,94,9,8,179,4,6,4,23,25,2,352,49,11,123,9,20,29,92,22,4,435,105,2,155,14,114,8,377,62,26,142,20,14,75,3,33,107,19,20,98,63,17,38,7,97,34,22,7,11,66,96,8,6,2,4,55,239,8],"type":"bar"},{"x":["achieving","practical","asymptotically","stochastic","efficiency","dimen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4584,), (4584, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.795

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discovery</span> <span style=''>of</span> <span style=''>Type</span> <span style=''>Classes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>Relations</span> <span style=''>in</span> <span style=''>Semantic</span> <span style=''>Web</span> <span style=''>Data</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>continuing</span> <span style='background-color:rgba(0, 255, 0, 0.48251748251748255);'>development</span> <span style=''>of</span> <span style=''>Semantic</span> <span style=''>Web</span> <span style='background-color:rgba(0, 255, 0, 0.7560975609756097);'>technologies</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3017751479289941);'>increasing</span> <span style=''>user</span> <span style=''>adoption</span> <span style=''>in</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerated</span> <span style=''>the</span> <span style=''>progress</span> <span style='background-color:rgba(0, 255, 0, 0.3469387755102042);'>incorporating</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.927927927927928);'>semantics</span> <span style=''>with</span> <span style=''>data</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Web</span> <span style=''>With</span> <span style=''>the</span> <span style=''>rapidly</span> <span style=''>growing</span> <span style=''>RDF</span> <span style=''>(Resource</span> <span style='background-color:rgba(0, 255, 0, 0.536842105263158);'>Description</span> <span style=''>Framework)</span> <span style=''>data</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Semantic</span> <span style=''>Web</span> <span style='background-color:rgba(0, 255, 0, 0.44416873449131533);'>processing</span> <span style=''>large</span> <span style=''>semantic</span> <span style=''>graph</span> <span style=''>data</span> <span style=''>have</span> <span style=''>become</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.41752577319587636);'>challenging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constructing</span> <span style=''>a</span> <span style=''>summary</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>from</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>RDF</span> <span style=''>can</span> <span style=''>help</span> <span style=''>obtain</span> <span style=''>semantic</span> <span style=''>type</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>relations</span> <span style=''>and</span> <span style=''>reduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>for</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.44416873449131533);'>processing</span> <span style=''>purposes</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>addressed</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.7000000000000001);'>summarization</span> <span style=''>in</span> <span style=''>RDF</span> <span style=''>graphs</span> <span style=''>and</span> <span style=''>we</span> <span style=''>proposed</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>building</span> <span style=''>summary</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dense</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributions</span> <span style=''>from</span> <span style=''>Sparse</span> <span style=''>Samples</span> <span style=''>Improved</span> <span style=''>Gibbs</span> <span style=''>Sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimators</span> <span style=''>for</span> <span style=''>LDA</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>(LDA)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collapsed</span> <span style=''>Gibbs</span> <span style=''>samples</span> <span style=''>(CGS)</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraging</span> <span style=''>the</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assignments</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>average</span> <span style=''>over</span> <span style=''>multiple</span> <span style=''>samples</span> <span style=''>for</span> <span style=''>little</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>than</span> <span style=''>drawing</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collapsed</span> <span style=''>Gibbs</span> <span style=''>sample</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>as</span> <span style=''>adapting</span> <span style=''>the</span> <span style=''>soft</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Collapsed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayes</span> <span style=''>(CVB0)</span> <span style=''>to</span> <span style=''>CGS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>get</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforwardly</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>any</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemen ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>with</span> <span style=''>possible</span> <span style=''>sensor</span> <span style=''>failures</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>large</span> <span style=''>margin</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>when</span> <span style=''>corrupt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalies</span> <span style=''>caused</span> <span style=''>by</span> <span style=''>sensor</span> <span style=''>failure</span> <span style=''>might</span> <span style=''>be</span> <span style=''>present</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>on</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>controlling</span> <span style=''>the</span> <span style=''>false</span> <span style=''>alarm</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalous</span> <span style=''>samples</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3469387755102042);'>incorporating</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.42465753424657526);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.705128205128205);'>estimator</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Geometric</span> <span style=''>Entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style='background-color:rgba(255, 0, 0, 0.4166666666666666);'>regularized</span> <span style=''>Maximum</span> <span style=''>Entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrimination</span> <span style=''>(GEM</span> <span style=''>MED)</span> <span style=''>method</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>and</span> <span style=''>detect</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalies</span> <span style=''>in</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>manner</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3640552995391705);'>simulated</span> <span style=''>data</span> <span style=''>and</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>models</span> <span style=''>from</span> <span style=''>image</span> <span style=''>pixels</span> <br/><br/><span style=''>Modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disciplines</span> <span style=''>eg</span> <span style=''>control</span> <span style=''>robotics</span> <span style=''>or</span> <span style=''>neurotechnology</span> <span style=''>Commonly</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>these</span> <span style=''>systems</span> <span style=''>is</span> <span style=''>not</span> <span style=''>directly</span> <span style=''>observed</span> <span style=''>but</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>through</span> <span style=''>noisy</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>In</span> <span style=''>these</span> <span style=''>cases</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>ie</span> <span style=''>finding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style=''>mapping</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>mapping</span> <span style=''>(system</span> <span style=''>dynamics)</span> <span style=''>in</span> <span style=''>latent</span> <span style=''>space</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>For</span> <span style=''>linear</span> <span style=''>system</span> <span style=''>dynamics</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style=''>mappings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>for</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>However</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>linearity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>does</span> <span style=''>not</span> <span style=''>hold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>If</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additionally</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>are</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>(eg</span> <span style=''>images)</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07501794687724336)
# 	processing (0.1044508255563532)
# 	representation (0.1353194544149318)
# 	experimental (0.1349605168700646)
# 	segmentation (0.07430007178750897)
# 	detection (0.1145010768126346)
# 	information (0.24838478104809764)
# 	different (0.25915290739411345)
# 	convolutional (0.14429289303661164)
# 	recognition (0.14213926776740848)
#
# Some Statistics words are:
# 	theoretical (0.15143992055610725)
# 	algorithm (0.38182720953326715)
# 	statistical (0.15739821251241312)
# 	variables (0.14349553128103276)
# 	stochastic (0.14498510427010924)
# 	distribution (0.18470705064548162)
# 	estimation (0.18520357497517378)
# 	dimensional (0.19016881827209534)
# 	inference (0.20109235352532273)
# 	regression (0.19215491559086395)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b674e7e3-cfaa-4e37-9c8b-df3e6943a182" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b674e7e3-cfaa-4e37-9c8b-df3e6943a182")) {                    Plotly.newPlot(                        "b674e7e3-cfaa-4e37-9c8b-df3e6943a182",                        [{"x":["achieving","practical","asymptotically","stochastic","efficiency","dimension","estimates","deterministic","variables","independently","computational","understanding","providing","asymptotic","interesting","minimization","functionals","nonlinear","numerical","effective","algorithm","solutions","characterized","information","component","associated","simulations","empirical","exploiting","performance","coordinate","statistical","efficiently","particular","independent","dimensional","decoupled","algorithms","dimensions","efficient","optimization","broadcast","environment","intelligent","broadcasting","distribute","geographical","vehicular","emergency","dissemination","contention","reduction","describes","environments","adaptivity","classical","complexity","outperforms","scenarios","dependent","knowledge","sometimes","consecutive","parameter","challenge","augmented","experiments","interpreted","determine","distributions","homogeneous","attributes","classifier","conducted","construction","classification","detection","directions","aggregating","regression","iterative","architecture","separated","predictions","converges","convolutional","quantized","probabilistic","previously","application","difficulty","capturing","encountered","automatically","hierarchical","approximations","extraction","different","assumption","predictive","typically","intractable","variational","collections","demonstrate","significantly","regularities","unobserved","estimated","procedure","indicative","inference","applicable","traditional","approaches","formatting","including","locations","gazetteer","heuristic","experimental","travelling","inferring","identification","predicted","prediction","predicting","variations","classifiers","geographic","granularities","dictionary","suboptimal","discriminant","convergence","considers","literature","conditions","observations","consistent","theoretical","selection","distributed","behaviours","simulating","potential","metaphors","institutional","institutions","aggregate","identifies","overarching","techniques","designing","architectural","structures","reproduce","specialized","behaviour","intelligence","proposing","conceived","applications","components","interfacing","artificial","organization","challenges","narrative","representation","integration","interpret","resulting","ontologies","disambiguation","background","polysemous","extending","semantics","discourse","constructs","languages","interpretation","systematically","functional","procedural","demonstrated","controlled","preprocessing","automating","observational","adaptation","importance","widespread","justification","employment","counterfactual","answering","representations","accumulation","healthcare","algorithmic","education","framework","questions","comparison","medication","increasing","combinations","detecting","landcover","accurately","researchers","satellite","comparing","combination","combining","stabilizing","exploration","externally","adversarial","strategies","oblivious","probabilities","sufficient","observation","conceptually","approximated","guarantees","adversary","essentially","designated","surprisingly","perturbed","worsening","introduce","ensembles","polygonal","connected","functions","ensembling","properties","understood","connectivity","geometric","performing","relevancy","effectively","generalize","thousands","tightening","decomposing","partition","fractional","generalization","compression" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	correlational
# 	ultrametric
# 	dendrogram
# 	regularised
# 	penalization
# 	autoencoding
# 	uncorrelated
# 	cubically
# 	coherently
# 	purchasing
# 	commonalities
# 	minimizers
# 	detectability
# 	intracellular
# 	amortization
# 	preconditioned
# 	censoring
# 	covariates
# 	anonymization
# 	inhomogeneity
# Some words which never appear in Statistics papers:
# 	broadcast
# 	vehicular
# 	dissemination
# 	contention
# 	formatting
# 	gazetteer
# 	travelling
# 	geographic
# 	metaphors
# 	institutional
# 	narrative
# 	discourse
# 	landcover
# 	directing
# 	indonesia
# 	sentential
# 	comparatively
# 	monochromatic
# 	discourage
# 	evidential

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082234003205524e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
